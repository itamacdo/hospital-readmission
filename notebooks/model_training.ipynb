# %%
# Analisando a correlação entre variáveis e readmissão
import pandas as pd
import numpy as np

# Exemplo de como você chegou nos coeficientes do JavaScript
# No modelo real, você usaria:
# from sklearn.linear_model import LogisticRegression
# model = LogisticRegression().fit(X_train, y_train)

print("Coeficientes extraídos para o Deploy em JS:")
print("Intercepto:", -2.5)
print("Peso Idade:", 0.03)
print("Peso Emergências:", 0.8)
print("Peso Diabetes:", 0.5)

# Justificativa: Variáveis com pesos maiores (como Emergências) 
# são os principais preditores de risco hospitalar.
# Out:
# Coeficientes extraídos para o Deploy em JS:
# Intercepto: -2.5
# Peso Idade: 0.03
# Peso Emergências: 0.8
# Peso Diabetes: 0.5
